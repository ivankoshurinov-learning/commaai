# %%
# 01. Загрузка и первичный анализ данных comma.ai

В этом ноутбуке:
- подключаю файлы `log/*.h5`;
- смотрю структуру данных;
- делаю базовый EDA (распределения, пропуски, выбросы).

# %%
from pathlib import Path

import h5py
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

plt.style.use("seaborn-v0_8")

DATA_ROOT = Path("../data/raw/dataset/log")
print("DATA_ROOT:", DATA_ROOT.resolve())
print("Data path exists:", DATA_ROOT.exists())

# %%
## Список доступных файлов `*.h5`

После распаковки архива здесь будет список файлов с телеметрией.
