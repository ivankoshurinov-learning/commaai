# %%
# 02. Предобработка и формирование признаков

План:
- очистка данных (фильтры по физическим ограничениям, выбросы, пропуски);
- формирование целевой переменной `maneuver_class` из `steering_angle`;
- разбиение на train / validation / test по поездкам.
