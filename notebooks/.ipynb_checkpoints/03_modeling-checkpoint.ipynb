# %%
# 03. Моделирование и оценка качества

План:
- baseline (DummyClassifier);
- логистическая регрессия;
- RandomForestClassifier;
- сравнение метрик на train / validation / test;
- анализ переобучения.
